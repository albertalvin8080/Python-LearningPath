# %%
import cv2 as cv
import albumentations as A
import os
import sys
import datetime
import io

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.layers import (
    Conv2D,
    MaxPool2D,
    Dense,
    Flatten,
    Input,
    BatchNormalization,
    Layer,
    InputLayer,
    Dropout,
    Resizing,
    Rescaling,
    RandomFlip,
    RandomRotation,
)
from tensorflow.keras.losses import (
    BinaryCrossentropy,
    CategoricalCrossentropy,
    SparseCategoricalCrossentropy,
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import (
    CategoricalAccuracy,
    TopKCategoricalAccuracy,
)
from tensorflow.keras.callbacks import (
    Callback,
    CSVLogger,
    EarlyStopping,
    LearningRateScheduler,
    ModelCheckpoint,
    ReduceLROnPlateau,
)
from tensorflow.keras.regularizers import L2, L1
import tensorflow_probability as tfp
from tensorboard.plugins.hparams import api as hp

import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.metrics import confusion_matrix, roc_curve

# from google.colab import drive
# drive.mount('/content/drive')
# TRAIN_DIR = "/content/drive/MyDrive/tfds_data/datasets/Emotions Dataset/Emotions Dataset/train"
# TEST_DIR = "/content/drive/MyDrive/tfds_data/datasets/Emotions Dataset/Emotions Dataset/test"

TRAIN_DIR = "./datasets/Emotions Dataset/Emotions Dataset/train"
TEST_DIR = "./datasets/Emotions Dataset/Emotions Dataset/test"
CLASS_NAMES = ["angry", "happy", "sad"]  # This needs to be in accord with dir names.

CONFIG = {
    "batch_size": 32,
    "im_shape": (256, 256),
    "im_size": 256,
    "input_shape": (None, None, 3),
    "filters_1": 6,
    "filters_2": 16,
    "kernel_size": 3,
    "activation_1": "relu",
    "activation_2": "softmax",
    "dropout": 0.01,
    # "dropout": 0.00,
    "regularization_l2": 0.1,
    # "regularization_l2": 0.0,
    "optimizer": "adam",
    "loss": "binary_crossentropy",
    "pool_size": 2,
    "strides_1": 1,
    "strides_2": 2,
    "dense_1": 32,
    "dense_2": 32,
    "dense_3": 32,
    "dense_out": 3,
    "learning_rate": 0.001,
    "batch_size": 32,
    "epochs": 5,
}
# Out:
# /home/albert/.local/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2024-11-06 14:42:28.893935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730914949.164989     671 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730914949.238624     671 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 14:42:29.937080: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    # NOTE: int -> [0,1,2]; categorical -> (1,0,0) | (0,1,0) | (0,0,1)
    label_mode="categorical",
    class_names=CLASS_NAMES,
    color_mode="rgb",
    batch_size=CONFIG["batch_size"],
    # batch_size=None,
    image_size=CONFIG["im_shape"],
    shuffle=True,
    seed=10,
).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    # NOTE: int -> 0 | 1 | 2; categorical -> (1,0,0) | (0,1,0) | (0,0,1)
    label_mode="categorical",
    class_names=CLASS_NAMES,
    color_mode="rgb",
    batch_size=CONFIG["batch_size"],
    # batch_size=None,
    image_size=CONFIG["im_shape"],
    shuffle=True,
    seed=10,
)
# Out:
# Found 6799 files belonging to 3 classes.
# I0000 00:00:1730914972.579877     671 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2865 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1
# Found 2278 files belonging to 3 classes.

# %%
# from google.colab import drive

# drive.mount('/content/drive')class CustomConv2D(Layer):

# !unzip "/content/drive/MyDrive/tfds_data/datasets.zip" -d "/content/drive/MyDrive/tfds_data/datasets/"

# %%
# It's basically a tf.keras.layers.Conv2D but with a tf.keras.layers.BatchNormalizer internally.
class CustomConv2D(Layer):
    def __init__(
        self,
        filters,
        kernel_size,
        strides,
        padding="valid",
        activation="relu",
        name="custom_conv_2d",
    ):
        super(CustomConv2D, self).__init__(name=name)

        self.conv2d = Conv2D(
            filters=filters,
            kernel_size=kernel_size,
            activation=activation,
            strides=strides,
            padding=padding,
        )

        self.batch_norm = BatchNormalization()

    def call(self, input, training=True):
        x = self.conv2d(input)
        x = self.batch_norm(x, training=training)
        return x


class ResidualBlock(Layer):
    def __init__(
        self, channel_size, strides=1, activation="relu", name="residual_block"
    ):
        super(ResidualBlock, self).__init__(name=name)

        self.conv1 = CustomConv2D(
            filters=channel_size, kernel_size=3, strides=strides, padding="same"
        )
        self.conv2 = CustomConv2D(
            filters=channel_size, kernel_size=3, strides=1, padding="same"
        )

        # If the number of strides is greater than one, it means that
        # the shape of the input variable passed to the call(...) method
        # is different from the shape of the output of the first Conv2D
        # layer (self.conv1).
        # See `resnet34_residual_blocks.png` to know more.
        self.dotted = strides != 1

        if self.dotted:
            # Used to make the `input` variable have the same shape as
            # the output of the first Conv2D layer of this ResidualBlock.
            self.conv3 = CustomConv2D(
                filters=channel_size,
                kernel_size=1,
                strides=strides,
            )

        self.activation = tf.keras.layers.Activation(activation)

    def call(self, input, training=True):
        x = self.conv1(input, training=training)
        x = self.conv2(x, training=training)

        # Converting the input to the shape of x if necessary.
        shortcut = self.conv3(input, training=training) if self.dotted else input

        x = tf.keras.layers.Add()([x, shortcut])
        return self.activation(x)


# See `resnet34_architecture.png` for more details.
class ResNet34(Model):
    def __init__(self, name="resnet_34"):
        super(ResNet34, self).__init__(name=name)

        self.conv1 = CustomConv2D(filters=64, kernel_size=7, strides=2, padding="same")
        # self.max_pool = tf.keras.layers.MaxPool2D(3, 2) # Is it the same? If not, it may have caused overfitting.
        self.max_pool = tf.keras.layers.MaxPooling2D(3, 2)

        self.conv2_1 = ResidualBlock(64)
        self.conv2_2 = ResidualBlock(64)
        self.conv2_3 = ResidualBlock(64)

        self.conv3_1 = ResidualBlock(128, 2)
        self.conv3_2 = ResidualBlock(128)
        self.conv3_3 = ResidualBlock(128)
        self.conv3_4 = ResidualBlock(128)

        self.conv4_1 = ResidualBlock(256, 2)
        self.conv4_2 = ResidualBlock(256)
        self.conv4_3 = ResidualBlock(256)
        self.conv4_4 = ResidualBlock(256)
        self.conv4_5 = ResidualBlock(256)
        self.conv4_6 = ResidualBlock(256)

        self.conv5_1 = ResidualBlock(512, 2)
        self.conv5_2 = ResidualBlock(512)
        self.conv5_3 = ResidualBlock(512)

        self.global_pool = tf.keras.layers.GlobalAveragePooling2D()
        self.fc_3 = Dense(len(CLASS_NAMES), activation="softmax")

    def call(self, input, training=True):
        x = self.conv1(input, training=training)
        x = self.max_pool(x, training=training)

        x = self.conv2_1(x, training=training)
        x = self.conv2_2(x, training=training)
        x = self.conv2_3(x, training=training)

        x = self.conv3_1(x, training=training)
        x = self.conv3_2(x, training=training)
        x = self.conv3_3(x, training=training)
        x = self.conv3_4(x, training=training)

        x = self.conv4_1(x, training=training)
        x = self.conv4_2(x, training=training)
        x = self.conv4_3(x, training=training)
        x = self.conv4_4(x, training=training)
        x = self.conv4_5(x, training=training)
        x = self.conv4_6(x, training=training)

        x = self.conv5_1(x, training=training)
        x = self.conv5_2(x, training=training)
        x = self.conv5_3(x, training=training)

        x = self.global_pool(x)
        x = self.fc_3(x)

        return x

resnet34 = ResNet34()
resnet34(tf.zeros([1, 256, 256, 3]), training = False)  # building the model -- call(...) will be called.
resnet34.summary()
# Out:
# Model: "resnet_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_conv_2d (CustomConv2D)   │ ?                      │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │        74,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │        74,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │        74,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │       231,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │       296,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │       296,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │       296,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │       921,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     1,182,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     1,182,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     1,182,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     1,182,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     1,182,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     3,677,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     4,723,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ ?                      │     4,723,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (1, 3)                 │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,311,747 (81.30 MB)
#  Trainable params: 21,294,723 (81.23 MB)
#  Non-trainable params: 17,024 (66.50 KB)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "resnet34.keras",
    monitor="val_categorical_accuracy",
    mode="max",
    verbose=1,
    save_best_only=True,
    initial_value_threshold=None,
)

metrics = [CategoricalAccuracy(), TopKCategoricalAccuracy(k=2)]

resnet34.compile(
    optimizer=Adam(learning_rate=CONFIG["learning_rate"] * 100),
    loss=CategoricalCrossentropy(from_logits=False),
    metrics=metrics,
)

history = resnet34.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=CONFIG["epochs"]*12,
    verbose=1,
    callbacks=[model_checkpoint],
)
# Out:
# Epoch 1/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - categorical_accuracy: 0.4355 - loss: 3.7107 - top_k_categorical_accuracy: 0.7402
# Epoch 1: val_categorical_accuracy improved from -inf to 0.37489, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 188s 709ms/step - categorical_accuracy: 0.4356 - loss: 3.7016 - top_k_categorical_accuracy: 0.7403 - val_categorical_accuracy: 0.3749 - val_loss: 24.7516 - val_top_k_categorical_accuracy: 0.7239
# Epoch 2/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - categorical_accuracy: 0.4852 - loss: 1.0448 - top_k_categorical_accuracy: 0.7721
# Epoch 2: val_categorical_accuracy improved from 0.37489 to 0.44864, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.4852 - loss: 1.0447 - top_k_categorical_accuracy: 0.7721 - val_categorical_accuracy: 0.4486 - val_loss: 192981.1875 - val_top_k_categorical_accuracy: 0.7809
# Epoch 3/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - categorical_accuracy: 0.4786 - loss: 1.0423 - top_k_categorical_accuracy: 0.7722
# Epoch 3: val_categorical_accuracy improved from 0.44864 to 0.46576, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 656ms/step - categorical_accuracy: 0.4786 - loss: 1.0423 - top_k_categorical_accuracy: 0.7722 - val_categorical_accuracy: 0.4658 - val_loss: 6211121152.0000 - val_top_k_categorical_accuracy: 0.7335
# Epoch 4/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.4895 - loss: 1.0346 - top_k_categorical_accuracy: 0.7725
# Epoch 4: val_categorical_accuracy did not improve from 0.46576
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 645ms/step - categorical_accuracy: 0.4895 - loss: 1.0346 - top_k_categorical_accuracy: 0.7725 - val_categorical_accuracy: 0.3213 - val_loss: 20211105267712.0000 - val_top_k_categorical_accuracy: 0.7959
# Epoch 5/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.4926 - loss: 1.0341 - top_k_categorical_accuracy: 0.7790
# Epoch 5: val_categorical_accuracy did not improve from 0.46576
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 645ms/step - categorical_accuracy: 0.4926 - loss: 1.0341 - top_k_categorical_accuracy: 0.7790 - val_categorical_accuracy: 0.3323 - val_loss: 2203043.7500 - val_top_k_categorical_accuracy: 0.7423
# Epoch 6/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.4817 - loss: 1.0370 - top_k_categorical_accuracy: 0.7794
# Epoch 6: val_categorical_accuracy did not improve from 0.46576
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.4817 - loss: 1.0370 - top_k_categorical_accuracy: 0.7794 - val_categorical_accuracy: 0.4122 - val_loss: 29153.8789 - val_top_k_categorical_accuracy: 0.7678
# Epoch 7/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.5108 - loss: 1.0144 - top_k_categorical_accuracy: 0.7949
# Epoch 7: val_categorical_accuracy improved from 0.46576 to 0.48639, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 659ms/step - categorical_accuracy: 0.5108 - loss: 1.0143 - top_k_categorical_accuracy: 0.7949 - val_categorical_accuracy: 0.4864 - val_loss: 713841856.0000 - val_top_k_categorical_accuracy: 0.7968
# Epoch 8/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.5168 - loss: 0.9737 - top_k_categorical_accuracy: 0.8018
# Epoch 8: val_categorical_accuracy improved from 0.48639 to 0.50439, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 657ms/step - categorical_accuracy: 0.5169 - loss: 0.9737 - top_k_categorical_accuracy: 0.8018 - val_categorical_accuracy: 0.5044 - val_loss: 1.0359 - val_top_k_categorical_accuracy: 0.7709
# Epoch 9/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - categorical_accuracy: 0.5532 - loss: 0.9351 - top_k_categorical_accuracy: 0.8142
# Epoch 9: val_categorical_accuracy did not improve from 0.50439
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 649ms/step - categorical_accuracy: 0.5532 - loss: 0.9351 - top_k_categorical_accuracy: 0.8142 - val_categorical_accuracy: 0.5018 - val_loss: 15993828016128.0000 - val_top_k_categorical_accuracy: 0.8161
# Epoch 10/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.5731 - loss: 0.9060 - top_k_categorical_accuracy: 0.8334
# Epoch 10: val_categorical_accuracy improved from 0.50439 to 0.52941, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 141s 660ms/step - categorical_accuracy: 0.5732 - loss: 0.9059 - top_k_categorical_accuracy: 0.8334 - val_categorical_accuracy: 0.5294 - val_loss: 2419099648.0000 - val_top_k_categorical_accuracy: 0.7893
# Epoch 11/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.5861 - loss: 0.8663 - top_k_categorical_accuracy: 0.8480
# Epoch 11: val_categorical_accuracy did not improve from 0.52941
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 648ms/step - categorical_accuracy: 0.5861 - loss: 0.8663 - top_k_categorical_accuracy: 0.8480 - val_categorical_accuracy: 0.5259 - val_loss: 128342228992.0000 - val_top_k_categorical_accuracy: 0.7972
# Epoch 12/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - categorical_accuracy: 0.6097 - loss: 0.8353 - top_k_categorical_accuracy: 0.8612
# Epoch 12: val_categorical_accuracy improved from 0.52941 to 0.57814, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 141s 662ms/step - categorical_accuracy: 0.6097 - loss: 0.8353 - top_k_categorical_accuracy: 0.8613 - val_categorical_accuracy: 0.5781 - val_loss: 39364628480.0000 - val_top_k_categorical_accuracy: 0.8402
# Epoch 13/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.6361 - loss: 0.8011 - top_k_categorical_accuracy: 0.8762
# Epoch 13: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.6361 - loss: 0.8011 - top_k_categorical_accuracy: 0.8762 - val_categorical_accuracy: 0.4131 - val_loss: 86015069518823424.0000 - val_top_k_categorical_accuracy: 0.7932
# Epoch 14/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - categorical_accuracy: 0.6431 - loss: 0.7794 - top_k_categorical_accuracy: 0.8744
# Epoch 14: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 650ms/step - categorical_accuracy: 0.6432 - loss: 0.7793 - top_k_categorical_accuracy: 0.8744 - val_categorical_accuracy: 0.5531 - val_loss: 381650010112.0000 - val_top_k_categorical_accuracy: 0.7937
# Epoch 15/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - categorical_accuracy: 0.6655 - loss: 0.7498 - top_k_categorical_accuracy: 0.8879
# Epoch 15: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 648ms/step - categorical_accuracy: 0.6655 - loss: 0.7497 - top_k_categorical_accuracy: 0.8879 - val_categorical_accuracy: 0.4899 - val_loss: 738847958861195771904.0000 - val_top_k_categorical_accuracy: 0.7629
# Epoch 16/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.6734 - loss: 0.7236 - top_k_categorical_accuracy: 0.8918
# Epoch 16: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.6734 - loss: 0.7236 - top_k_categorical_accuracy: 0.8918 - val_categorical_accuracy: 0.3753 - val_loss: 9163273188677376802816.0000 - val_top_k_categorical_accuracy: 0.6510
# Epoch 17/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.6993 - loss: 0.6903 - top_k_categorical_accuracy: 0.8993
# Epoch 17: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.6993 - loss: 0.6902 - top_k_categorical_accuracy: 0.8993 - val_categorical_accuracy: 0.5004 - val_loss: 471386451607552.0000 - val_top_k_categorical_accuracy: 0.8117
# Epoch 18/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.7131 - loss: 0.6612 - top_k_categorical_accuracy: 0.9074
# Epoch 18: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.7131 - loss: 0.6611 - top_k_categorical_accuracy: 0.9074 - val_categorical_accuracy: 0.4258 - val_loss: 4762015646223433728.0000 - val_top_k_categorical_accuracy: 0.7011
# Epoch 19/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7193 - loss: 0.6382 - top_k_categorical_accuracy: 0.9112
# Epoch 19: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.7193 - loss: 0.6382 - top_k_categorical_accuracy: 0.9112 - val_categorical_accuracy: 0.5193 - val_loss: 89107523281354752.0000 - val_top_k_categorical_accuracy: 0.7985
# Epoch 20/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - categorical_accuracy: 0.7477 - loss: 0.5954 - top_k_categorical_accuracy: 0.9245
# Epoch 20: val_categorical_accuracy did not improve from 0.57814
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 650ms/step - categorical_accuracy: 0.7477 - loss: 0.5954 - top_k_categorical_accuracy: 0.9245 - val_categorical_accuracy: 0.3639 - val_loss: 173770339526901760.0000 - val_top_k_categorical_accuracy: 0.6383
# Epoch 21/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.7458 - loss: 0.6037 - top_k_categorical_accuracy: 0.9235
# Epoch 21: val_categorical_accuracy improved from 0.57814 to 0.60667, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 659ms/step - categorical_accuracy: 0.7458 - loss: 0.6037 - top_k_categorical_accuracy: 0.9235 - val_categorical_accuracy: 0.6067 - val_loss: 111288230489626771456.0000 - val_top_k_categorical_accuracy: 0.8613
# Epoch 22/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7580 - loss: 0.5879 - top_k_categorical_accuracy: 0.9217
# Epoch 22: val_categorical_accuracy improved from 0.60667 to 0.68745, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 658ms/step - categorical_accuracy: 0.7580 - loss: 0.5879 - top_k_categorical_accuracy: 0.9217 - val_categorical_accuracy: 0.6874 - val_loss: 12155757789184.0000 - val_top_k_categorical_accuracy: 0.8736
# Epoch 23/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7788 - loss: 0.5485 - top_k_categorical_accuracy: 0.9257
# Epoch 23: val_categorical_accuracy improved from 0.68745 to 0.70676, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 657ms/step - categorical_accuracy: 0.7788 - loss: 0.5485 - top_k_categorical_accuracy: 0.9257 - val_categorical_accuracy: 0.7068 - val_loss: 6952484701311336448.0000 - val_top_k_categorical_accuracy: 0.9061
# Epoch 24/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7972 - loss: 0.5099 - top_k_categorical_accuracy: 0.9407
# Epoch 24: val_categorical_accuracy did not improve from 0.70676
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.7971 - loss: 0.5100 - top_k_categorical_accuracy: 0.9407 - val_categorical_accuracy: 0.3512 - val_loss: 2268926264213504.0000 - val_top_k_categorical_accuracy: 0.5926
# Epoch 25/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.7914 - loss: 0.5051 - top_k_categorical_accuracy: 0.9410
# Epoch 25: val_categorical_accuracy did not improve from 0.70676
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.7914 - loss: 0.5051 - top_k_categorical_accuracy: 0.9410 - val_categorical_accuracy: 0.6115 - val_loss: 24728645402624.0000 - val_top_k_categorical_accuracy: 0.8270
# Epoch 26/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.8141 - loss: 0.4757 - top_k_categorical_accuracy: 0.9428
# Epoch 26: val_categorical_accuracy improved from 0.70676 to 0.71378, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 659ms/step - categorical_accuracy: 0.8141 - loss: 0.4757 - top_k_categorical_accuracy: 0.9429 - val_categorical_accuracy: 0.7138 - val_loss: 499717700059136.0000 - val_top_k_categorical_accuracy: 0.9074
# Epoch 27/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.8247 - loss: 0.4455 - top_k_categorical_accuracy: 0.9474
# Epoch 27: val_categorical_accuracy improved from 0.71378 to 0.71730, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 140s 657ms/step - categorical_accuracy: 0.8247 - loss: 0.4455 - top_k_categorical_accuracy: 0.9474 - val_categorical_accuracy: 0.7173 - val_loss: 2483939180544.0000 - val_top_k_categorical_accuracy: 0.9043
# Epoch 28/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.8305 - loss: 0.4322 - top_k_categorical_accuracy: 0.9545
# Epoch 28: val_categorical_accuracy did not improve from 0.71730
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.8305 - loss: 0.4322 - top_k_categorical_accuracy: 0.9545 - val_categorical_accuracy: 0.5711 - val_loss: 3506536644779966464.0000 - val_top_k_categorical_accuracy: 0.8200
# Epoch 29/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - categorical_accuracy: 0.8442 - loss: 0.4025 - top_k_categorical_accuracy: 0.9588
# Epoch 29: val_categorical_accuracy improved from 0.71730 to 0.75417, saving model to resnet34.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 141s 662ms/step - categorical_accuracy: 0.8442 - loss: 0.4025 - top_k_categorical_accuracy: 0.9588 - val_categorical_accuracy: 0.7542 - val_loss: 0.6680 - val_top_k_categorical_accuracy: 0.9280
# Epoch 30/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - categorical_accuracy: 0.8423 - loss: 0.3946 - top_k_categorical_accuracy: 0.9535
# Epoch 30: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 139s 650ms/step - categorical_accuracy: 0.8423 - loss: 0.3946 - top_k_categorical_accuracy: 0.9535 - val_categorical_accuracy: 0.6953 - val_loss: 2412756665892864.0000 - val_top_k_categorical_accuracy: 0.8876
# Epoch 31/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - categorical_accuracy: 0.8603 - loss: 0.3610 - top_k_categorical_accuracy: 0.9668
# Epoch 31: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 649ms/step - categorical_accuracy: 0.8603 - loss: 0.3610 - top_k_categorical_accuracy: 0.9668 - val_categorical_accuracy: 0.7063 - val_loss: 1548113177214976.0000 - val_top_k_categorical_accuracy: 0.8797
# Epoch 32/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 594ms/step - categorical_accuracy: 0.8625 - loss: 0.3514 - top_k_categorical_accuracy: 0.9670
# Epoch 32: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 649ms/step - categorical_accuracy: 0.8622 - loss: 0.3521 - top_k_categorical_accuracy: 0.9669 - val_categorical_accuracy: 0.3319 - val_loss: 110190787592978432.0000 - val_top_k_categorical_accuracy: 0.9996
# Epoch 33/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.6168 - loss: 0.8221 - top_k_categorical_accuracy: 0.8649
# Epoch 33: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.6169 - loss: 0.8219 - top_k_categorical_accuracy: 0.8650 - val_categorical_accuracy: 0.5132 - val_loss: 1771361335980851200.0000 - val_top_k_categorical_accuracy: 0.8003
# Epoch 34/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.7176 - loss: 0.6724 - top_k_categorical_accuracy: 0.9034
# Epoch 34: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.7176 - loss: 0.6723 - top_k_categorical_accuracy: 0.9034 - val_categorical_accuracy: 0.5707 - val_loss: 0.9992 - val_top_k_categorical_accuracy: 0.8073
# Epoch 35/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7654 - loss: 0.5691 - top_k_categorical_accuracy: 0.9297
# Epoch 35: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 645ms/step - categorical_accuracy: 0.7654 - loss: 0.5691 - top_k_categorical_accuracy: 0.9297 - val_categorical_accuracy: 0.5676 - val_loss: 1195822848.0000 - val_top_k_categorical_accuracy: 0.7270
# Epoch 36/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.7972 - loss: 0.4990 - top_k_categorical_accuracy: 0.9453
# Epoch 36: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.7972 - loss: 0.4990 - top_k_categorical_accuracy: 0.9453 - val_categorical_accuracy: 0.6479 - val_loss: 87909994510294439690240.0000 - val_top_k_categorical_accuracy: 0.8424
# Epoch 37/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.8141 - loss: 0.4664 - top_k_categorical_accuracy: 0.9486
# Epoch 37: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 645ms/step - categorical_accuracy: 0.8142 - loss: 0.4663 - top_k_categorical_accuracy: 0.9486 - val_categorical_accuracy: 0.6212 - val_loss: 1251572572969420980224.0000 - val_top_k_categorical_accuracy: 0.8472
# Epoch 38/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.8444 - loss: 0.3922 - top_k_categorical_accuracy: 0.9619
# Epoch 38: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.8444 - loss: 0.3921 - top_k_categorical_accuracy: 0.9619 - val_categorical_accuracy: 0.6185 - val_loss: 3120370541608328622959924730658816.0000 - val_top_k_categorical_accuracy: 0.8802
# Epoch 39/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.8458 - loss: 0.3963 - top_k_categorical_accuracy: 0.9634
# Epoch 39: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 647ms/step - categorical_accuracy: 0.8458 - loss: 0.3963 - top_k_categorical_accuracy: 0.9634 - val_categorical_accuracy: 0.6681 - val_loss: 147832438784000.0000 - val_top_k_categorical_accuracy: 0.8942
# Epoch 40/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.8791 - loss: 0.3258 - top_k_categorical_accuracy: 0.9697
# Epoch 40: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.8791 - loss: 0.3257 - top_k_categorical_accuracy: 0.9697 - val_categorical_accuracy: 0.6773 - val_loss: 0.9026 - val_top_k_categorical_accuracy: 0.9122
# Epoch 41/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.8848 - loss: 0.3150 - top_k_categorical_accuracy: 0.9722
# Epoch 41: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 645ms/step - categorical_accuracy: 0.8847 - loss: 0.3152 - top_k_categorical_accuracy: 0.9722 - val_categorical_accuracy: 0.6958 - val_loss: 291730150653952.0000 - val_top_k_categorical_accuracy: 0.8547
# Epoch 42/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.8064 - loss: 0.4933 - top_k_categorical_accuracy: 0.9404
# Epoch 42: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.8064 - loss: 0.4935 - top_k_categorical_accuracy: 0.9404 - val_categorical_accuracy: 0.5799 - val_loss: 17729973125120.0000 - val_top_k_categorical_accuracy: 0.8661
# Epoch 43/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.8454 - loss: 0.4066 - top_k_categorical_accuracy: 0.9581
# Epoch 43: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.8454 - loss: 0.4066 - top_k_categorical_accuracy: 0.9581 - val_categorical_accuracy: 0.6475 - val_loss: 1369941526400529858560.0000 - val_top_k_categorical_accuracy: 0.8687
# Epoch 44/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.7875 - loss: 0.5404 - top_k_categorical_accuracy: 0.9360
# Epoch 44: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 645ms/step - categorical_accuracy: 0.7875 - loss: 0.5402 - top_k_categorical_accuracy: 0.9361 - val_categorical_accuracy: 0.6975 - val_loss: 21243585276897872838656.0000 - val_top_k_categorical_accuracy: 0.9008
# Epoch 45/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.8797 - loss: 0.3302 - top_k_categorical_accuracy: 0.9699
# Epoch 45: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 138s 646ms/step - categorical_accuracy: 0.8797 - loss: 0.3301 - top_k_categorical_accuracy: 0.9699 - val_categorical_accuracy: 0.7362 - val_loss: 96562335934075732275778027520.0000 - val_top_k_categorical_accuracy: 0.9214
# Epoch 46/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - categorical_accuracy: 0.9123 - loss: 0.2469 - top_k_categorical_accuracy: 0.9791
# Epoch 46: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.9124 - loss: 0.2468 - top_k_categorical_accuracy: 0.9791 - val_categorical_accuracy: 0.6286 - val_loss: 224936138101365570390384967680.0000 - val_top_k_categorical_accuracy: 0.8723
# Epoch 47/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - categorical_accuracy: 0.9236 - loss: 0.2109 - top_k_categorical_accuracy: 0.9857
# Epoch 47: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 643ms/step - categorical_accuracy: 0.9236 - loss: 0.2109 - top_k_categorical_accuracy: 0.9857 - val_categorical_accuracy: 0.6291 - val_loss: 553098836377785878936813568.0000 - val_top_k_categorical_accuracy: 0.8898
# Epoch 48/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - categorical_accuracy: 0.9239 - loss: 0.2154 - top_k_categorical_accuracy: 0.9840
# Epoch 48: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 643ms/step - categorical_accuracy: 0.9239 - loss: 0.2155 - top_k_categorical_accuracy: 0.9840 - val_categorical_accuracy: 0.4614 - val_loss: nan - val_top_k_categorical_accuracy: 0.9153
# Epoch 49/60
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - categorical_accuracy: 0.9310 - loss: 0.1948 - top_k_categorical_accuracy: 0.9873
# Epoch 49: val_categorical_accuracy did not improve from 0.75417
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 137s 644ms/step - categorical_accuracy: 0.9311 - loss: 0.1948 - top_k_categorical_accuracy: 0.9873 - val_categorical_accuracy: 0.7186 - val_loss: nan - val_top_k_categorical_accuracy: 0.9008
# Epoch 50/60
#  86/213 ━━━━━━━━━━━━━━━━━━━━ 1:15 594ms/step - categorical_accuracy: 0.9336 - loss: 0.1903 - top_k_categorical_accuracy: 0.9902

# %%
plt.figure()
plt.plot(history.history["categorical_accuracy"])
plt.plot(history.history["val_categorical_accuracy"])
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure()
# ----> 2 plt.plot(history.history["categorical_accuracy"])
#       3 plt.plot(history.history["val_categorical_accuracy"])
#       4 plt.xlabel("epochs")
#
# NameError: name 'history' is not defined
