# %% [markdown]
# ### Loading Data

# %%
import pandas as pd

df = pd.read_csv("pokemon_data.txt", delimiter="\t")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df[["Name", "Attack", "#"]][0:5]
# Out:
#                     Name  Attack  #
# 0              Bulbasaur      49  1
# 1                Ivysaur      62  2
# 2               Venusaur      82  3
# 3  VenusaurMega Venusaur     100  3
# 4             Charmander      52  4

# %%
# df.iloc[160:170]
# df.iloc[160:170, [1,2]]
df.iloc[160:170, 1:3]
# Out:
#                     Name   Type 1
# 160            Dragonair   Dragon
# 161            Dragonite   Dragon
# 162               Mewtwo  Psychic
# 163  MewtwoMega Mewtwo X  Psychic
# 164  MewtwoMega Mewtwo Y  Psychic
# 165                  Mew  Psychic
# 166            Chikorita    Grass
# 167              Bayleef    Grass
# 168             Meganium    Grass
# 169            Cyndaquil     Fire

# %%
df["Generation"] > 5
# type(df["Generation"] > 5) # pandas.core.series.Series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Generation, Length: 800, dtype: bool

# %%
# df[df["Generation"] > 5]                         # Less flexible

# Order: Row / Column
df.loc[df["Generation"] > 5, ["Name", "Attack"]]   # More flexible as you can see
# df.loc[["Name", "Attack"], df["Generation"] > 5] # Error: Unalignable boolean Series provided as indexer
# Out:
#                     Name  Attack
# 718              Chespin      61
# 719            Quilladin      78
# 720           Chesnaught     107
# 721             Fennekin      45
# 722              Braixen      59
# ..                   ...     ...
# 795              Diancie     100
# 796  DiancieMega Diancie     160
# 797  HoopaHoopa Confined     110
# 798   HoopaHoopa Unbound     160
# 799            Volcanion     110
#
# [82 rows x 2 columns]

# %%
# df.loc[["Name", "Attack"]] # Error (row parameter missing)
df.loc[:, ["Name", "Attack"]] # Success

# %%
for index, row in df.iterrows():
    print(index, "-" * 21)
    print("->", row["Type 1"])
    print(row)
# Out:
# 0 ---------------------
# -> Grass
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 ---------------------
# -> Grass
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 ---------------------
# -> Grass
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# ...
