# %%
import pandas as pd
import numpy as np

df = pd.read_csv("pokemon_data.csv")

# %%
# Inserts at the end
df["Dead"] = [np.nan] * len(df)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Dead
# 0         65       65     45           1      False   NaN
# ...

# %%
data = [False] * len(df)
df.insert(0, column="Alive", value=data, allow_duplicates=True)
# df.drop(labels="Alive", axis=1, inplace=True) # Removes all columns with "Alive" as label.
df
# Out:
#      Alive    #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0    False    1              Bulbasaur    Grass  Poison  45      49       49
# 1    False    2                Ivysaur    Grass  Poison  60      62       63
# 2    False    3               Venusaur    Grass  Poison  80      82       83
# 3    False    3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4    False    4             Charmander     Fire     NaN  39      52       43
# ..     ...  ...                    ...      ...     ...  ..     ...      ...
# 795  False  719                Diancie     Rock   Fairy  50     100      150
# 796  False  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  False  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  False  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  False  721              Volcanion     Fire   Water  80     110      120
#
# ...

# %%
# Returns a new DataFrame because of `inplace=False`) without the columns which have the label "Alive".
dftemp = df.drop(labels="Alive", axis=1, inplace=False) 
dftemp = df.drop(columns="Alive", inplace=False) # Same behavior
dftemp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 2
#       1 # Returns a new DataFrame because of `inplace=False`) without the columns which have the label "Alive".
# ----> 2 dftemp = df.drop(labels="Alive", axis=1, inplace=False)
#       3 dftemp = df.drop(columns="Alive", inplace=False)
#       4 dftemp
#
# File c:\Users\Albert\Documents\A_Programacao\_GITIGNORE\Learning_Python\Pandas\.venv\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# ...

# %%
data = [True] * len(df)
# df.assign({"BadPoke":data, "Adopted":True}) # No, **kwargs (keywords) are not dictionaries.
df.assign(BadPoke=data, Adopted=True)[:5] # Returns a copy DF containing the new column.
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  BadPoke  Adopted
# 0       65     45           1      False     True     True
# 1       80     60           1      False     True     True
# 2      100     80           1      False     True     True
# 3      120     80           1      False     True     True
# 4       50     65           1      False     True     True

# %%
# df.drop([1,2,3], axis=0, inplace=False).reset_index()
# df.drop([1,2,3], axis=0, inplace=False)[:5]
df.drop(index=[1,2,3], inplace=False)[:5]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
